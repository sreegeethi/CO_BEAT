# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/Covid-detection/COUGH-SOUND-COV-DETECTION
# Out:
# /content/drive/MyDrive/Colab Notebooks/Covid-detection/COUGH-SOUND-COV-DETECTION

# %%
# !pip install pyAudioAnalysis

# %%
# !pip install eyed3

# %%
# !pip install pydub

# %% [markdown]
# SVM

# %%
from pyAudioAnalysis import audioTrainTest as aT
aT.extract_features_and_train(['train/COVID','train/HEALTHY'], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svm_model", False)
# Out:
# Analyzing file 1 of 1001: train/COVID/015576c8-2b03-4dcb-b251-78a984fe86fe.wav
# Analyzing file 2 of 1001: train/COVID/031fd54a-87b5-4223-9af6-60985127fb7a.wav
# Analyzing file 3 of 1001: train/COVID/0379c586-c500-483c-83a6-95b63afe6931.wav
# Analyzing file 4 of 1001: train/COVID/03d30b8b-03f8-4089-bda8-0e14deec7d82.wav
# Analyzing file 5 of 1001: train/COVID/06b568b5-b9f8-4334-816c-c16009bb5de7.wav
# Analyzing file 6 of 1001: train/COVID/080b6119-f1ab-4337-93dd-aaccf73b4ee1.wav
# Analyzing file 7 of 1001: train/COVID/082991fb-ee66-4970-91dd-50890f4cc9b1.wav
# Analyzing file 8 of 1001: train/COVID/0837bd59-09c5-4098-afe3-4bcbfb0fb0e2.wav
# Analyzing file 9 of 1001: train/COVID/08d5d346-6219-4e6d-ac06-ef489f2d186c.wav
# Analyzing file 10 of 1001: train/COVID/09115490-33a9-461c-9437-d7f71be057b0.wav
# Analyzing file 11 of 1001: train/COVID/0b0d7e10-8353-4124-a16b-bf96e405f63c.wav
# Analyzing file 12 of 1001: train/COVID/0c35e382-31cd-42cb-bc87-8a84b9c52a41.wav
# ...

# %%
import plotly
import plotly.subplots
from pyAudioAnalysis import audioTrainTest as aT
cm, thr_prre, pre, rec, thr_roc, fpr, tpr = aT.evaluate_model_for_folders(["test/COVID","test/HEALTHY"], "svm_model", "svm","COVID")
# Out:
# [[ 76  50]
#  [ 15 111]]
# [0.6031746031746031, 0.8809523809523809] [0.8351648351648352, 0.6894409937888198] [0.7004608294930876, 0.7735191637630662] 0.7369899966280768 0.7420634920634921

# %%
import seaborn as sn
import matplotlib.pyplot as plt

plt.figure(figsize=(9,6))
sn.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth value')
# Out:
# Text(60.0, 0.5, 'Truth value')

# %%
acc=(76+111)/(76+50+15+111)

print(" Accuracy : {0:.2f}".format(acc*100))
# Out:
#  Accuracy : 74.21

# %% [markdown]
# SVM WITH RBF KERNEL

# %%
from pyAudioAnalysis import audioTrainTest as aT
aT.extract_features_and_train(['train/COVID','train/HEALTHY'], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm_rbf", "svm_rbf_model", False)
# Out:
# Analyzing file 1 of 1001: train/COVID/015576c8-2b03-4dcb-b251-78a984fe86fe.wav
# Analyzing file 2 of 1001: train/COVID/031fd54a-87b5-4223-9af6-60985127fb7a.wav
# Analyzing file 3 of 1001: train/COVID/0379c586-c500-483c-83a6-95b63afe6931.wav
# Analyzing file 4 of 1001: train/COVID/03d30b8b-03f8-4089-bda8-0e14deec7d82.wav
# Analyzing file 5 of 1001: train/COVID/06b568b5-b9f8-4334-816c-c16009bb5de7.wav
# Analyzing file 6 of 1001: train/COVID/080b6119-f1ab-4337-93dd-aaccf73b4ee1.wav
# Analyzing file 7 of 1001: train/COVID/082991fb-ee66-4970-91dd-50890f4cc9b1.wav
# Analyzing file 8 of 1001: train/COVID/0837bd59-09c5-4098-afe3-4bcbfb0fb0e2.wav
# Analyzing file 9 of 1001: train/COVID/08d5d346-6219-4e6d-ac06-ef489f2d186c.wav
# Analyzing file 10 of 1001: train/COVID/09115490-33a9-461c-9437-d7f71be057b0.wav
# Analyzing file 11 of 1001: train/COVID/0b0d7e10-8353-4124-a16b-bf96e405f63c.wav
# Analyzing file 12 of 1001: train/COVID/0c35e382-31cd-42cb-bc87-8a84b9c52a41.wav
# ...

# %%
import plotly
import plotly.subplots
cm, thr_prre, pre, rec, thr_roc, fpr, tpr = aT.evaluate_model_for_folders(["test/COVID","test/HEALTHY"], "svm_rbf_model", "svm","COVID")
# Out:
# [[ 76  50]
#  [ 16 110]]
# [0.6031746031746031, 0.873015873015873] [0.8260869565217391, 0.6875] [0.6972477064220184, 0.7692307692307692] 0.7332392378263938 0.7380952380952381

# %%
plt.figure(figsize=(9,6))
sn.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth value')
# Out:
# Text(60.0, 0.5, 'Truth value')

# %%
acc=(76+110)/(76+50+16+110)

print(" Accuracy : {0:.2f}".format(acc*100))
# Out:
#  Accuracy : 73.81

# %% [markdown]
# GRADIENT BOOSTING

# %%
from pyAudioAnalysis import audioTrainTest as aT
aT.extract_features_and_train(['train/COVID','train/HEALTHY'], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "gradientboosting", "gb_model", False)
# Out:
# Analyzing file 1 of 1001: train/COVID/015576c8-2b03-4dcb-b251-78a984fe86fe.wav
# Analyzing file 2 of 1001: train/COVID/031fd54a-87b5-4223-9af6-60985127fb7a.wav
# Analyzing file 3 of 1001: train/COVID/0379c586-c500-483c-83a6-95b63afe6931.wav
# Analyzing file 4 of 1001: train/COVID/03d30b8b-03f8-4089-bda8-0e14deec7d82.wav
# Analyzing file 5 of 1001: train/COVID/06b568b5-b9f8-4334-816c-c16009bb5de7.wav
# Analyzing file 6 of 1001: train/COVID/080b6119-f1ab-4337-93dd-aaccf73b4ee1.wav
# Analyzing file 7 of 1001: train/COVID/082991fb-ee66-4970-91dd-50890f4cc9b1.wav
# Analyzing file 8 of 1001: train/COVID/0837bd59-09c5-4098-afe3-4bcbfb0fb0e2.wav
# Analyzing file 9 of 1001: train/COVID/08d5d346-6219-4e6d-ac06-ef489f2d186c.wav
# Analyzing file 10 of 1001: train/COVID/09115490-33a9-461c-9437-d7f71be057b0.wav
# Analyzing file 11 of 1001: train/COVID/0b0d7e10-8353-4124-a16b-bf96e405f63c.wav
# Analyzing file 12 of 1001: train/COVID/0c35e382-31cd-42cb-bc87-8a84b9c52a41.wav
# ...

# %%
import plotly
import plotly.subplots
cm, thr_prre, pre, rec, thr_roc, fpr, tpr = aT.evaluate_model_for_folders(["test/COVID","test/HEALTHY"], "gb_model", "gradientboosting","COVID")
# Out:
# [[ 78  48]
#  [ 21 105]]
# [0.6190476190476191, 0.8333333333333334] [0.7878787878787878, 0.6862745098039216] [0.6933333333333334, 0.7526881720430109] 0.7230107526881722 0.7261904761904762

# %%
(78+105)/(48+21+78+105)
# Out:
# 0.7261904761904762

# %%
# CONSIDERING ONLY cough-heavy.wav from coswara (New folders were created by removing cough-shallow.wav)

# %% [markdown]
# SVM

# %%
from pyAudioAnalysis import audioTrainTest as aT
aT.extract_features_and_train(['Dataset/train/COVID','Dataset/train/HEALTHY'], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm_rbf", "svm_model_2", False)
# Out:
# Analyzing file 1 of 808: Dataset/train/COVID/031fd54a-87b5-4223-9af6-60985127fb7a.wav
# Analyzing file 2 of 808: Dataset/train/COVID/03d30b8b-03f8-4089-bda8-0e14deec7d82.wav
# Analyzing file 3 of 808: Dataset/train/COVID/0640716b-e287-4181-a653-5b798e8308c8.wav
# Analyzing file 4 of 808: Dataset/train/COVID/06b568b5-b9f8-4334-816c-c16009bb5de7.wav
# Analyzing file 5 of 808: Dataset/train/COVID/080b6119-f1ab-4337-93dd-aaccf73b4ee1.wav
# Analyzing file 6 of 808: Dataset/train/COVID/082991fb-ee66-4970-91dd-50890f4cc9b1.wav
# Analyzing file 7 of 808: Dataset/train/COVID/0837bd59-09c5-4098-afe3-4bcbfb0fb0e2.wav
# Analyzing file 8 of 808: Dataset/train/COVID/08d5d346-6219-4e6d-ac06-ef489f2d186c.wav
# Analyzing file 9 of 808: Dataset/train/COVID/09115490-33a9-461c-9437-d7f71be057b0.wav
# Analyzing file 10 of 808: Dataset/train/COVID/0aa64689-c48a-421d-b353-c3496bad51ed.wav
# Analyzing file 11 of 808: Dataset/train/COVID/0b03673a-28db-4e1c-aeb0-4fec88d977a1.wav
# ...

# %%
import plotly
import plotly.subplots
from pyAudioAnalysis import audioTrainTest as aT
cm, thr_prre, pre, rec, thr_roc, fpr, tpr = aT.evaluate_model_for_folders(["Dataset/test/COVID","Dataset/test/HEALTHY"], "svm_model_2", "svm_rbf","COVID")
# Out:
# [[107  97]
#  [ 10 244]]
# [0.5245098039215687, 0.9606299212598425] [0.9145299145299145, 0.7155425219941349] [0.6666666666666666, 0.8201680672268907] 0.7434173669467787 0.7663755458515283

# %%
(107+244)/(10+244+107+97)
# Out:
# 0.7663755458515283

# %%
aT.extract_features_and_train(['Dataset/train/COVID','Dataset/train/HEALTHY'], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svm_model_3", False)
# Out:
# Analyzing file 1 of 808: Dataset/train/COVID/031fd54a-87b5-4223-9af6-60985127fb7a.wav
# Analyzing file 2 of 808: Dataset/train/COVID/03d30b8b-03f8-4089-bda8-0e14deec7d82.wav
# Analyzing file 3 of 808: Dataset/train/COVID/0640716b-e287-4181-a653-5b798e8308c8.wav
# Analyzing file 4 of 808: Dataset/train/COVID/06b568b5-b9f8-4334-816c-c16009bb5de7.wav
# Analyzing file 5 of 808: Dataset/train/COVID/080b6119-f1ab-4337-93dd-aaccf73b4ee1.wav
# Analyzing file 6 of 808: Dataset/train/COVID/082991fb-ee66-4970-91dd-50890f4cc9b1.wav
# Analyzing file 7 of 808: Dataset/train/COVID/0837bd59-09c5-4098-afe3-4bcbfb0fb0e2.wav
# Analyzing file 8 of 808: Dataset/train/COVID/08d5d346-6219-4e6d-ac06-ef489f2d186c.wav
# Analyzing file 9 of 808: Dataset/train/COVID/09115490-33a9-461c-9437-d7f71be057b0.wav
# Analyzing file 10 of 808: Dataset/train/COVID/0aa64689-c48a-421d-b353-c3496bad51ed.wav
# Analyzing file 11 of 808: Dataset/train/COVID/0b03673a-28db-4e1c-aeb0-4fec88d977a1.wav
# ...

# %%
import plotly
import plotly.subplots
from pyAudioAnalysis import audioTrainTest as aT
cm, thr_prre, pre, rec, thr_roc, fpr, tpr = aT.evaluate_model_for_folders(["Dataset/test/COVID","Dataset/test/HEALTHY"], "svm_model_3", "svm","COVID")
# Out:
# [[104 100]
#  [  5 249]]
# [0.5098039215686274, 0.9803149606299213] [0.9541284403669725, 0.7134670487106017] [0.6645367412140575, 0.8258706467661692] 0.7452036939901133 0.7707423580786026

# %%
(104+249)/(104+100+5+249)
# Out:
# 0.7707423580786026
